# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
from pathlib import Path
dir = os.path.realpath('..')
# `cwd`: current directory is straightforward
# cwd = Path.cwd()
# datfile = r'calibration_data/RampTest_2022-01-13_202229.csv'
# datfile = r'calibration_data/StepsTest_2022-01-13_202828.csv'
# datfile = r'calibration_data/8.csv'
datfile = r'calibration_data/pitch_tuning.csv'
fname = os.path.join(dir, datfile)

df = pd.read_csv(fname)

# %%
df['time_s']=(df['imu_time_ns'] - df['imu_time_ns'][0] ) /np.power(10,9)
df.time_s[0] = 0.0
# Out:
# <ipython-input-3-e6ba6401c482>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.time_s[0] = 0.0

# %%
print(df.columns.to_list())
# Out:
# ['loop_index', 'last_step_ns', 'imu_time_ns', 'bmp_time_ns', 'epoch_time_ns', 'v_batt', 'alt_bmp_raw', 'bmp_temp', 'gyro_roll', 'gyro_pitch', 'gyro_yaw', 'accel_X', 'accel_Y', 'accel_Z', 'mag_X', ' mag_Y', ' mag_Z', 'roll', 'pitch', 'yaw', 'rollDot', 'pitchDot', 'yawDot', 'X', 'Y', 'Z', 'Xdot', 'Ydot', 'Zdot', 'Zddot', 'xbee_time', 'xbee_time_received_ns', 'xbee_x', 'xbee_y', 'xbee_z', 'xbee_qw', 'xbee_qx', 'xbee_qy', 'xbee_qz', 'xbee_roll', 'xbee_pitch', 'xbee_yaw', 'gps_lat', 'gps_lon', 'gps_gpsAlt', 'gps_ned_x', 'gps_ned_y', 'gps_ned_z', 'gps_spd', 'gps_fix', 'gps_sat', 'gps_headingNc', 'gps_cog', 'gps_gpsVsi', 'gps_hdop', 'gps_vdop', 'gps_year', 'gps_month', 'gps_day', 'gps_hour', 'gps_minute', 'gps_second', 'gps_time_received_ns', 'X_thrt', 'Y_thrt', 'Z_thrt', 'roll_thrt', 'pitch_thrt', 'yaw_thrt', 'sp_roll_dot', 'sp_pitch_dot', 'sp_yaw_dot', 'sp_roll_dot_ff', 'sp_pitch_dot_ff', 'sp_yaw_dot_ff', 'sp_roll', 'sp_pitch', 'sp_yaw', 'sp_roll_ff', 'sp_pitch_ff', 'sp_X', 'sp_Y', 'sp_Z'
# ...

# %%
plt.plot(df['time_s'][40000:43000],df['pitch'][40000:43000])
plt.plot(df['time_s'][40000:43000],df['sp_pitch'][40000:43000])

# %%
df.query('sp_pitch>.9')
# Out:
#        loop_index         last_step_ns          imu_time_ns  \
# 790           791  1643687584656967269  1643687584656603186
# 791           792  1643687584661979311  1643687584661657686
# 792           793  1643687584666879728  1643687584666575061
# 793           794  1643687584671879353  1643687584671580519
# 794           795  1643687584676926936  1643687584676558519
# ...           ...                  ...                  ...
# 42662       42663  1643687793842959378  1643687793842629711
# 42663       42664  1643687793847885086  1643687793847569919
# 42664       42665  1643687793852901419  1643687793852538753
# 42665       42666  1643687793857871003  1643687793857561711
# 42666       42667  1643687793862848086  1643687793862545169
#
#                bmp_time_ns        epoch_time_ns   v_batt  alt_bmp_raw  \
# 790    1643687584656603186  1643687584656970603  15.5244     217.6397
# 791    1643687584661657686  1643687584661982811  15.5242     217.6397
# ...

# %%
datfile = r'calibration_data/roll_tuning.csv'
fname = os.path.join(dir, datfile)

df = pd.read_csv(fname)
df['time_s']=(df['imu_time_ns'] - df['imu_time_ns'][0] ) /np.power(10,9)
df.time_s[0] = 0.0
# Out:
# <ipython-input-7-2103d53ed9e9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.time_s[0] = 0.0

# %%
# tslice = [0:]
plt.plot(df['time_s'],df['roll'])
plt.plot(df['time_s'],df['sp_roll'])

# %%
df.query('sp_roll<-.9 and 60<time_s<80')
# Out:
#        loop_index         last_step_ns          imu_time_ns  \
# 13504       13505  1643688759737201826  1643688759736869284
# 13505       13506  1643688759742182243  1643688759741842701
# 13506       13507  1643688759747112618  1643688759746790951
# 13507       13508  1643688759752079493  1643688759751778909
# 13508       13509  1643688759757184118  1643688759756856076
# ...           ...                  ...                  ...
# 14120       14121  1643688762814882951  1643688762814476160
# 14121       14122  1643688762819779576  1643688762819424160
# 14122       14123  1643688762824636285  1643688762824311410
# 14123       14124  1643688762829634118  1643688762829314701
# 14124       14125  1643688762834723368  1643688762834380993
#
#                bmp_time_ns        epoch_time_ns   v_batt  alt_bmp_raw  \
# 13504  1643688759736869284  1643688759737205784  15.0701     220.9530
# 13505  1643688759741842701  1643688759742186034  15.0723     220.9530
# ...

# %%
df = df[12400:14120:]
plt.plot(df['time_s'],df['roll'])
plt.plot(df['time_s'],df['sp_roll'])

# %%
df[12000::]
# Out:
# Empty DataFrame
# ...
